# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTTextLine, LTChar
from pypdf import PdfReader
import re

# %% [markdown]
# # ***Tạo hàm xử lý các chun***

# %%
# Xác định format của chunk được sử dụng:

# {
#   "id": "3-2-1",
#   "values": [0.123, -0.456, ...],
#   "metadata": {
#     "subject": "Lịch sử ĐCSVN",
#     "chapter": "Chương III",
#     "chapter_title": "Chương III: Đường lối kháng chiến",
#     "section": "II.",
#     "section_title": "II. Giai đoạn đầu",
#     "subsection": "1.",
#     "subsection_title": "1. Tư tưởng chỉ đạo",
#     "content": "...",
#     "position_in_document": 73,
#     "tokens": 296,
#     "type": "theory"
#   }
# }

# %%
def parse_chapters(text):
    """
    Hàm được sử dụng để tách 1 đoạn chương thành 2 thành phần là số chương và title của chương đó
    """
    chapters_data = []
    pattern = re.compile(r"(Chương\s(?:nhập môn|\d+))\s*(.*)")

    for line in text.strip().split('\n'):
        match = pattern.match(line)
        if match:
            chapter_number = match.group(1).strip()
            chapter_title = match.group(2).strip()
            chapters_data.append({
                'chapter': chapter_number,
                'chapter_title': chapter_title
            })
    return chapter_number, chapter_title

# %%
def build_chunk(
    chapter_line,
    section_line,
    sub_section_line,
    content_line,
    position_in_document=0,
    model=None  # model dùng để embedding nếu muốn
):
    if chapter_line != "":
        chapter_number, chapter_title = parse_chapters(chapter_line)
    else:
        chapter_number, chapter_title = None

    # Xử lý mục (section)
    if section_line != "":
        section = section_line.strip().split()[0]  # lấy "II."
        section_title = section_line.strip()
    else:
        section = None
        section_title = None

    # Xử lý tiểu mục (subsection)
    if sub_section_line != "":
        subsection = sub_section_line.strip().split()[0]  # lấy "1."
        subsection_title = sub_section_line.strip()
    else:
        subsection = None
        subsection_title = None
        
    return chapter_number, chapter_title, section, section_title, subsection, subsection_title

# %% [markdown]
# # ***Xử lý các phần chú thích ở cuối trang***

# %%
pdf_path = "../data/LichSuDang/lich_su_dang.pdf"

#Tạo fulltext để chứa toàn bộ các dòng chử trong file Lịch sử Đảng
sections = []

# Lấy số trang trong file PDF
reader = PdfReader(pdf_path)
total_pages = len(reader.pages)
print("Số trang trong PDF:", total_pages)
# Out:
# Số trang trong PDF: 219

# %%
pdf_path = "../data/LichSuDang/lich_su_dang.pdf"

def chunking_LSD(pdf_path):
    chapter_title = []
    section_title = []
    sub_section_title = []
    content = []

    is_content = False

    curr_chapter_line = ""
    curr_section_line = ""
    curr_sub_section_line = ""
    curr_content_line = ""

    #Duyệt qua từng trang trong file pdf, bắt đầu từ trang 2 (bỏ qua trang bìa)
    for page_layout in extract_pages(pdf_path, page_numbers=range(2, total_pages)):
        
        #Duyệt qua từng phần tử trong trang
        for element in page_layout:
            if isinstance(element, LTTextContainer):

                # Duyet qua từng dòng chữ trong phần tử
                for text_line in element:
                    if isinstance(text_line, LTTextLine):
                        
                        #Lấy ra từng kí tự bên trong dòng chữ
                        for obj in text_line:
                            if isinstance(obj, LTChar):
                                '''
                                Dựa vào kích thước chữ để phân loại các phần trong tài liệu
                                - Kích thước chữ = 14: Chương và tiêu đề của chương - Done
                                - Kích thước chữ = 13, vừa in đậm vừa in nghiêng: Tiêu đề phụ (1 nhỏ, 2 nhỏ, 3 nhỏ, ...) - Done
                                - Kích thước chữ = 13, chỉ in đậm không in nghiêng: Tiêu đề lớn ( 1 la mã, 2 la mã, 3 la mã, ...), Mục Tiêu ( Chú ý xử lý trường hợp này) - Done
                                - Kích thước chữ > 12.9: Các nội dung chính
                                - Kích thước chữ = 12: Số trang - Done
                                - Kích thước chữ < 11: Nội dung phụ, chú thích, ghi chú (Loại bỏ các trường hợp này) - Done
                                '''
                                #Lấy ra thông tin của kí tự
                                font = obj.fontname
                                text = obj.get_text()
                                text_size = obj.size

                                if text_size == 14:    #Lấy ra các ký tự có kích thước chữ = 14, đây là tiêu đề chương

                                    #Nếu có nội dung chương trước đó thì đẩy 1 chunk
                                    if is_content == True:
                                        print(curr_chapter_line)
                                        print("1")
                                        print(curr_chapter_line)
                                        print(curr_section_line)
                                        print(curr_sub_section_line)
                                        is_content = False

                                    # curr_chapter_line =""
                                    curr_chapter_line += text

                                elif text_size >12.9 and text_size < 14:   #Lấy ra các ký tự có kích thước chữ > 12.9 (Đây là nội dung chính)

                                    #Tiêu đề la mã
                                    if ("Bold" in font) and ("Italic" not in font):
                                        #Nếu có nội dung chương trước đó thì đẩy 1 chunk
                                        if is_content == True:
                                            print(curr_chapter_line)
                                            print(curr_section_line)
                                            print(curr_sub_section_line)
                                            is_content = False

                                        # curr_section_line = ""
                                        curr_section_line += text
                                    
                                    #Tiêu đề phụ
                                    elif ("Italic" in font) and ("Bold" in font):
                                        #Nếu có nội dung chương trước đó thì đẩy 1 chunk
                                        if is_content == True:
                                            print(curr_chapter_line)
                                            print(curr_section_line)
                                            print(curr_sub_section_line)
                                            is_content = False

                                        # curr_sub_section_line =""
                                        curr_sub_section_line += text
                                    
                                    #Trường hợp là văn bản bình thường
                                    else:
                                        is_content = True
                                        curr_content_line += text
                        # print("Chapter:", curr_chapter_line)                    
                        # print("Section", curr_section_line)                    
                        # print("Subsection:", curr_sub_section_line) 
                        # print("==================================")                   
            # if curr_section_line.strip():  # chỉ thêm nếu có ký tự hợp lệ
            #     section_title.append(curr_section_line)
            #     curr_section_line = ""
            # if curr_sub_section_line.strip():  # chỉ thêm nếu có ký tự hợp lệ
            #     sub_section_title.append(curr_sub_section_line)
            #     curr_sub_section_line = ""
            # if curr_content_line.strip():  # chỉ thêm nếu có ký tự hợp lệ
            #     content.append(curr_content_line)
            #     curr_content_line = ""
    return chapter_title, section_title, sub_section_title, content

# %%
chapter_title, section_title, sub_section_title, content = chunking_LSD(pdf_path)
# Out:
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
#
#
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam
#
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.
#
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.2.
#
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.2.3.
#
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.2.3.4
# .
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.2.3.4II. Chức năng, nhiệm vụ của môn học Lịch sử Đảng Cộng sản Việt Nam
# .
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.2.3.4II. Chức năng, nhiệm vụ của môn học Lịch sử Đảng Cộng sản Việt Nam
# .1. Chức năng của khoa học Lịch sử Đảng
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam 1.2.3.4II. Chức năng, nhiệm vụ của môn học Lịch sử Đảng Cộng sản Việt Nam
# .1. Chức năng của khoa học Lịch sử Đảng2. Nhiệm vụ của khoa học Lịch sử Đảng
# Chương nhập mônĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT N
 Tổ quốc 1975-1981 2. Đại hội đại biểu toàn quốc lần thứ V của Đảng và các bước đột phá tiếp tục đổimới kinh tế 1982-1986 1. Đổi mới toàn diện, đưa đất nước ra khỏi khủng hoảng kinh tế - xã hội 1986-1996 2. Tiếp tục công cuộc đổi mới, đẩy mạnh công nghiệp hoá, hiện đại hoá và hộinhập quốc tế  1996-20183. Thành tựu, kinh nghiệm của công cuộc đổi mớiMột là, thắng lợi của cuộc Cách mạng Tháng Tám năm 1945, thành lập Nhànước Việt Nam Dân chủ Cộng hòaHai là, thắng lợi của các cuộc kháng chiến oanh liệt để giải phóng dân tộc, bảovệ Tổ quốcBa là, thắng lợi của sự nghiệp đổi mới và từng bước đưa đất nước quá độ lên chủnghĩa xã hội.1. Nắm vững ngọn cờ độc lập dân tộc và chủ nghĩa xã hội 2. Sự nghiệp cách mạng là của nhân dân, do nhân dân và vì nhân dân3. Không ngừng củng cố, tăng cường đoàn kết, đoàn kết toàn Đảng, đoàn kếttoàn dân, đoàn kết dân tộc, đoàn kết quốc tế4. Kết hợp sức mạnh dân tộc với sức mạnh thời đại, sức mạnh trong nước với sứcmạnh quốc tế5. Sự lãnh đạo đúng đắn của Đảng là nhân tố hàng đầu quyết định thắng lợi củacách mạng Việt Nam

# %%
chapter_title
# Out:
# []

# %%
section_title
# Out:
# []

# %%
sub_section_title
# Out:
# []

# %%
content
# Out:
# []

# %%
chapter_title = []
section_title = []
sub_section_title = []
content = []

is_content = False

curr_chapter_line = ""
curr_section_line = ""
curr_sub_section_line = ""
curr_content_line = ""

#Duyệt qua từng trang trong file pdf, bắt đầu từ trang 2 (bỏ qua trang bìa)
for page_layout in extract_pages(pdf_path, page_numbers=range(2, total_pages)):
    
    #Duyệt qua từng phần tử trong trang
    for element in page_layout:
        if isinstance(element, LTTextContainer):

            # Duyet qua từng dòng chữ trong phần tử
            for text_line in element:
                if isinstance(text_line, LTTextLine):
                    
                    #Lấy ra từng kí tự bên trong dòng chữ
                    for obj in text_line:
                        if isinstance(obj, LTChar):
                            '''
                            Dựa vào kích thước chữ để phân loại các phần trong tài liệu
                            - Kích thước chữ = 14: Chương và tiêu đề của chương - Done
                            - Kích thước chữ = 13, vừa in đậm vừa in nghiêng: Tiêu đề phụ (1 nhỏ, 2 nhỏ, 3 nhỏ, ...) - Done
                            - Kích thước chữ = 13, chỉ in đậm không in nghiêng: Tiêu đề lớn ( 1 la mã, 2 la mã, 3 la mã, ...), Mục Tiêu ( Chú ý xử lý trường hợp này) - Done
                            - Kích thước chữ > 12.9: Các nội dung chính
                            - Kích thước chữ = 12: Số trang - Done
                            - Kích thước chữ < 11: Nội dung phụ, chú thích, ghi chú (Loại bỏ các trường hợp này) - Done
                            '''
                            #Lấy ra thông tin của kí tự
                            font = obj.fontname
                            text = obj.get_text()
                            text_size = obj.size

                            if text_size == 14:    #Lấy ra các ký tự có kích thước chữ = 14, đây là tiêu đề chương

                                #Nếu có nội dung chương trước đó thì đẩy 1 chunk
                                if is_content == True:
                                    chapter_number, chapter_title, section, section_title, subsection, subsection_title = build_chunk(curr_chapter_line, curr_section_line, curr_sub_section_line, content)
                                    print("Chương hiện tại:       ", chapter_number)
                                    print("Tiêu đề chương:        ", chapter_title)
                                    print("Mục hiện tại:          ", section)
                                    print("Tiêu đề mục:           ", section_title)
                                    print("Mục con hiện tại:      ", subsection)
                                    print("Tiêu đề mục con:       ", subsection_title)
                                    print("Nội dung đoạn:         ", curr_content_line[:20], "...", curr_content_line[-20:], "------------", len(curr_content_line))
                                    print("======================================================================================================") 
                                    curr_chapter_line = ""
                                    curr_section_line = ""
                                    curr_sub_section_line = ""
                                    curr_content_line = ""
                                    is_content = False

                                # curr_chapter_line =""
                                curr_chapter_line += text

                            elif text_size >12.9 and text_size < 14:   #Lấy ra các ký tự có kích thước chữ > 12.9 (Đây là nội dung chính)

                                #Tiêu đề la mã
                                if ("Bold" in font) and ("Italic" not in font):
                                    #Nếu có nội dung chương trước đó thì đẩy 1 chunk
                                    if is_content == True:
                                        chapter_number, chapter_title, section, section_title, subsection, subsection_title = build_chunk(curr_chapter_line, curr_section_line, curr_sub_section_line, content)
                                        print("Chap hien tai:", chapter)
                                        print("Chương hiện tại:       ", chapter_number)
                                        print("Tiêu đề chương:        ", chapter_title)
                                        print("Mục hiện tại:          ", section)
                                        print("Tiêu đề mục:           ", section_title)
                                        print("Mục con hiện tại:      ", subsection)
                                        print("Tiêu đề mục con:       ", subsection_title)
                                        print("Nội dung đoạn:         ", curr_content_line[:20], "...", curr_content_line[-20:], "------------", len(curr_content_line))
                                        print("======================================================================================================") 
                                        curr_section_line = ""
                                        curr_sub_section_line = ""
                                        curr_content_line = ""
                                        is_content = False

                                    # curr_section_line = ""
                                    curr_section_line += text
                                
                                #Tiêu đề phụ
                                elif ("Italic" in font) and ("Bold" in font):
                                    #Nếu có nội dung chương trước đó thì đẩy 1 chunk
                                    if is_content == True:
                                        chapter_number, chapter_title, section, section_title, subsection, subsection_title = build_chunk(curr_chapter_line, curr_section_line, curr_sub_section_line, content)
                                        print("Chương hiện tại:       ", chapter_number)
                                        print("Tiêu đề chương:        ", chapter_title)
                                        print("Mục hiện tại:          ", section)
                                        print("Tiêu đề mục:           ", section_title)
                                        print("Mục con hiện tại:      ", subsection)
                                        print("Tiêu đề mục con:       ", subsection_title)
                                        print("Nội dung đoạn:         ", curr_content_line[:20], "...", curr_content_line[-20:], "------------", len(curr_content_line))
                                        print("======================================================================================================") 
                                        curr_sub_section_line = ""
                                        curr_content_line = ""
                                        is_content = False

                                    # curr_sub_section_line =""
                                    curr_sub_section_line += text
                                
                                #Trường hợp là văn bản bình thường
                                else:
                                    is_content = True
                                    curr_content_line += text
                    # print("Chapter:", curr_chapter_line)                    
                    # print("Section", curr_section_line)                    
                    # print("Subsection:", curr_sub_section_line) 
                    # print("======================================================================================================")                   
        # if curr_section_line.strip():  # chỉ thêm nếu có ký tự hợp lệ
        #     section_title.append(curr_section_line)
        #     curr_section_line = ""
        # if curr_sub_section_line.strip():  # chỉ thêm nếu có ký tự hợp lệ
        #     sub_section_title.append(curr_sub_section_line)
        #     curr_sub_section_line = ""
        # if curr_content_line.strip():  # chỉ thêm nếu có ký tự hợp lệ
        #     content.append(curr_content_line)
        #     curr_content_line = ""
# return chapter_title, section_title, sub_section_title, content
# Out:
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           None
# Tiêu đề mục:            None
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Đảng Cộng sản Việt N ... o quan điểm củaĐảng. ------------ 2168
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Đối tượng nghiên cứu của môn học Lịch sử Đảng Cộng sản Việt Nam
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Đối tượng nghiên cứu ... các thời kỳ lịch sử. ------------ 126
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           1.
# Tiêu đề mục:            1.
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:           Trước hết là các sự ... ng thực, khách quan. ------------ 1489
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           2.
# Tiêu đề mục:            2.
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:           Đảng lãnh đạo cách  ... ối đưa đến thắnglợi. ------------ 1433
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           3.
# Tiêu đề mục:            3.
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:           Đảng lãnh đạo thông ... a quốc tế trongsáng. ------------ 1635
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           4
# Tiêu đề mục:            4
# Mục con hiện tại:       .
# Tiêu đề mục con:        .
# Nội dung đoạn:           Nghiên cứu Lịch sử  ...  đảng viên hiện nay. ------------ 812
# ======================================================================================================
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Chức năng, nhiệm vụ của môn học Lịch sử Đảng Cộng sản Việt Nam
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Là một ngành của kho ...  điêm cấn nhấn mạnh. ------------ 148
# ======================================================================================================
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Chức năng, nhiệm vụ của môn học Lịch sử Đảng Cộng sản Việt Nam
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Chức năng của khoa học Lịch sử Đảng
# Nội dung đoạn:          Trước hết đó là chức ... n hóa” trong nội bộ. ------------ 3579
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Chức năng, nhiệm vụ của môn học Lịch sử Đảng Cộng sản Việt Nam
# Mục con hiện tại:       2.
# Tiêu đề mục con:        2. Nhiệm vụ của khoa học Lịch sử Đảng
# Nội dung đoạn:          Nhiệm vụ của khoa họ ...  Việt Nam anh hùng”. ------------ 3540
# ======================================================================================================
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           III.
# Tiêu đề mục:            III. Phương pháp nghiên cứu, học tập môn học Lịch sử Đảng Cộng sản ViệtNam
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Quán triệt phương pháp luận sử học
# Nội dung đoạn:          Phương pháp nghiên c ...  chủ quan duy ý chí. ------------ 1822
# ======================================================================================================
# Chương hiện tại:        Chương nhập môn
# Tiêu đề chương:         ĐỐI TƯỢNG, CHỨC NĂNG, NHIỆM VỤ,NỘI DUNG VÀ PHƯƠNG PHÁP NGHIÊN CỨU, HỌC TẬPLỊCH SỬ ĐẢNG CỘNG SẢN VIỆT NAM
# Mục hiện tại:           III.
# Tiêu đề mục:            III. Phương pháp nghiên cứu, học tập môn học Lịch sử Đảng Cộng sản ViệtNam
# Mục con hiện tại:       2.
# Tiêu đề mục con:        2. Các phương pháp cụ thể
# Nội dung đoạn:          Khoa học lịch sử và  ... a xã hội ở Việt Nam. ------------ 15401
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           None
# Tiêu đề mục:            None
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Về kiến thức:  ... Về kiến thức:  ------------ 14
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           MỤC
# Tiêu đề mục:            MỤC TIÊU
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Cung cấp cho sinh vi ... ính quyền cách mạng. ------------ 797
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Đảng Cộng sản Việt Nam ra đời và Cương lĩnh chính trị đầu tiên của Đảngtháng 2- 1930
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Bối cảnh lịch sử
# Nội dung đoạn:          Từ nửa sau thế kỷ XI ... giải phóng dân tộc.  ------------ 16382
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Đảng Cộng sản Việt Nam ra đời và Cương lĩnh chính trị đầu tiên của Đảngtháng 2- 1930
# Mục con hiện tại:       2.
# Tiêu đề mục con:        2. Nguyễn Ái Quốc chuẩn bị các điều kiện để thành lập Đảng
# Nội dung đoạn:          Trước yêu cầu cấp th ... g Cộng sản Việt Nam. ------------ 11512
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Đảng Cộng sản Việt Nam ra đời và Cương lĩnh chính trị đầu tiên của Đảngtháng 2- 1930
# Mục con hiện tại:       3.
# Tiêu đề mục con:        3. Thành lập Đảng Cộng sản Việt Nam và Cương lĩnh chính trị đầu tiên củaĐảng
# Nội dung đoạn:          Các tổ chức cộng sản ... ng một trang sử mới. ------------ 13111
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Đảng Cộng sản Việt Nam ra đời và Cương lĩnh chính trị đầu tiên của Đảngtháng 2- 1930
# Mục con hiện tại:       4.
# Tiêu đề mục con:        4. Ý nghĩa lịch sử của việc thành lập Đảng Cộng sản Việt Nam
# Nội dung đoạn:          Đảng Cộng sản Việt N ...  đến thắng lợi khác. ------------ 2508
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo quá trình đấu tranh giành chính quyền 1930-1945
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Phong trào cách mạng 1930-1931 và khôi phục phong trào 1932- 1935.
# Nội dung đoạn:          Phong trào cách mạng ... trào cách mạng mới.  ------------ 14525
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo quá trình đấu tranh giành chính quyền 1930-1945
# Mục con hiện tại:       2.
# Tiêu đề mục con:        2. Phong trào dân chủ 1936-1939
# Nội dung đoạn:          Điều kiện lịch sử và ... g Tháng Tám sau này. ------------ 10328
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo quá trình đấu tranh giành chính quyền 1930-1945
# Mục con hiện tại:       3.
# Tiêu đề mục con:        3. Phong trào giải phóng dân tộc 1939-1945
# Nội dung đoạn:          Bối cảnh lịch sử và  ...  giành chính quyền.  ------------ 34914
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo quá trình đấu tranh giành chính quyền 1930-1945
# Mục con hiện tại:       4.
# Tiêu đề mục con:        4. Tính chất, ý nghĩa và kinh nghiệm của Cách mạng Tháng Tám năm 1945
# Nội dung đoạn:          Tính chấtCách mạng T ... ớc dân chủ nhân dân. ------------ 7786
# ======================================================================================================
# Chương hiện tại:        Chương 1
# Tiêu đề chương:         ĐẢNG CỘNG SẢN VIỆT NAM RA ĐỜI VÀ LÃNH ĐẠO ĐẤU TRANH GIÀNH CHÍNH QUYỀN (1930 - 1945)
# Mục hiện tại:           NỘI
# Tiêu đề mục:            NỘI DUNG ÔN TẬP VÀ THẢO LUẬN
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          1. Phân tích những đ ... g ThángTám năm 1945. ------------ 377
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           None
# Tiêu đề mục:            None
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Về kiến thức: ... Về kiến thức: ------------ 13
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           MỤC
# Tiêu đề mục:            MỤC TIÊU
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Cung cấp cho sinh vi ... về lịch sử của Đảng. ------------ 676
# ======================================================================================================
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Lãnh đạo xây dựng, bảo vệ chính quyền cách mạng, kháng chiến chống thựcdân Pháp xâm lược 1945-1954
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Xây dựng và bảo vệ chính quyền cách mạng 1945-1946
# Nội dung đoạn:          Tình hình Việt Nam s ... giai đoạn 1945-1946. ------------ 22947
# ======================================================================================================
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Lãnh đạo xây dựng, bảo vệ chính quyền cách mạng, kháng chiến chống thựcdân Pháp xâm lược 1945-1954
# Mục con hiện tại:       2.
# Tiêu đề mục con:        2. Đường lối kháng chiến toàn quốc và quá trình tổ chức thực hiện từ năm 1946đến năm 1950
# Nội dung đoạn:          Cuộc kháng chiến toà ... phát triển cao hơn.  ------------ 19918
# ======================================================================================================
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Lãnh đạo xây dựng, bảo vệ chính quyền cách mạng, kháng chiến chống thựcdân Pháp xâm lược 1945-1954
# Mục con hiện tại:       3.
# Tiêu đề mục con:        3. Đẩy mạnh cuộc kháng chiến đến thắng lợi 1951-1954
# Nội dung đoạn:          Đại hội đại biểu toà ... cĐông Dương sau này. ------------ 19766
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Lãnh đạo xây dựng, bảo vệ chính quyền cách mạng, kháng chiến chống thựcdân Pháp xâm lược 1945-1954
# Mục con hiện tại:       4.
# Tiêu đề mục con:        4. Ý nghĩa lịch sử và kinh nghiệm của Đảng trong lãnh đạo kháng chiến chốngPháp và can thiệp Mỹ.
# Nội dung đoạn:          Ý nghĩa thắng lợi củ ... i Đảng và Chính phủ. ------------ 6219
# ======================================================================================================
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo xây dựng chủ nghĩa xã hội ở miền Bắc và kháng chiến chống đếquốc Mỹ xâm lược, giải phóng miền Nam, thống nhất đất nước 1954-1975
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Sự lãnh đạo của Đảng đối với cách mạng hai miền Nam - Bắc 1954-1965
# Nội dung đoạn:          Khôi phục kinh tế, c ... m tiếp tục tiến lên. ------------ 33891
# ======================================================================================================
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo xây dựng chủ nghĩa xã hội ở miền Bắc và kháng chiến chống đếquốc Mỹ xâm lược, giải phóng miền Nam, thống nhất đất nước 1954-1975
# Mục con hiện tại:       2.
# Tiêu đề mục con:        2. Lãnh đạo cách mạng cả nước 1965-1975
# Nội dung đoạn:          Đường lối kháng chiế ...  vĩ đại của dân tộc. ------------ 38325
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           II.
# Tiêu đề mục:            II. Lãnh đạo xây dựng chủ nghĩa xã hội ở miền Bắc và kháng chiến chống đếquốc Mỹ xâm lược, giải phóng miền Nam, thống nhất đất nước 1954-1975
# Mục con hiện tại:       3.
# Tiêu đề mục con:        3. Ý nghĩa lịch sử và kinh nghiệm lãnh đạo của Đảng thời kỳ 1954 - 1975
# Nội dung đoạn:          Ý nghĩa   Thắng lợi  ... a xã hội ở miền Bắc. ------------ 3665
# ======================================================================================================
# Chương hiện tại:        Chương 2
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO HAI CUỘC KHÁNG CHIẾN, HOÀN THÀNH GIẢI PHÓNG DÂN TỘC, THỐNG NHẤT ĐẤT NƯỚC (1945 - 1975)
# Mục hiện tại:           NỘI
# Tiêu đề mục:            NỘI DUNG ÔN TẬP VÀ THẢO LUẬN
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          1. Đường lối và sự c ... ởmiền Bắc 1954-1975. ------------ 562
# ======================================================================================================
# Chap hien tai: Chương 3ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Chương hiện tại:        Chương 3
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Mục hiện tại:           MỤC
# Tiêu đề mục:            MỤC TIÊU
# Mục con hiện tại:       None
# Tiêu đề mục con:        None
# Nội dung đoạn:          Về kiến thức: Giúp s ... hực tiễn cuộc sống.  ------------ 733
# ======================================================================================================
# Chương hiện tại:        Chương 3
# Tiêu đề chương:         ĐẢNG LÃNH ĐẠO CẢ NƯỚC QUÁ ĐỘ LÊNCHỦ NGHĨA XÃ HỘI VÀ TIẾN HÀNH CÔNG CUỘC ĐỔI MỚI(1975 - 2018)
# Mục hiện tại:           I.
# Tiêu đề mục:            I. Lãnh đạo cả nước xây dựng chủ nghĩa xã hội và bảo vệ Tổ quốc 1975-1986
# Mục con hiện tại:       1.
# Tiêu đề mục con:        1. Xây dựng chủ nghĩa xã hội và bảo vệ Tổ quốc 1975-1981
# Nội dung đoạn:          Hoàn cảnh lịch sử củ ... i đoạn mới: “Một là, ------------ 6380
# ======================================================================================================
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 69
#      66 if ("Bold" in font) and ("Italic" not in font):
#      67     #Nếu có nội dung chương trước đó thì đẩy 1 chunk
#      68     if is_content == True:
# ---> 69         chapter_number, chapter_title, section, section_title, subsection, subsection_title = build_chunk(curr_chapter_line, curr_section_line, curr_sub_section_line, content)
#      70         print("Chap hien tai:", chapter)
#      71         print("Chương hiện tại:       ", chapter_number)
#
# Cell In[32], line 24, in build_chunk(chapter_line, section_line, sub_section_line, content_line, position_in_document, model)
#      22 # Xử lý tiểu mục (subsection)
#      23 if sub_section_line != "":
# ---> 24     subsection = sub_section_line.strip().split()[0]  # lấy "1."
#      25     subsection_title = sub_section_line.strip()
#      26 else:
#
# IndexError: list index out of range

# %% [markdown]
# Các fontsize có trong giáo trình:
#     - {5.799999999999997,
#         7.5,
#         7.500000000000028,
#         9.999999999999986,
#         10.0,
#         10.000000000000007,
#         11.0,
#         11.000000000000007,
#         12.0,
#         12.999999999999943,
#         12.999999999999972,
#         12.999999999999993,
#         13.0,
#         13.000000000000007,
#         14.0,
#         14.000000000000007,
#         14.000000000000014,
#         16.0}
